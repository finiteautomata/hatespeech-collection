# %% [markdown]
# # Clarín
#
#
# En esta notebook veremos cómo andan los artículos de Clarín

# %%
# %load_ext autoreload
# %autoreload 2
from mongoengine import connect
from tweepyrate import create_apps
from hatespeech_models import Tweet, Article

client = connect("hatespeech-news")
db = client["hatespeech-news"]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
Article.objects.distinct('user')
# Out:
# ['LANACION',
#  'LaVanguardia',
#  'abc_es',
#  'clarincom',
#  'cronica',
#  'elmundoes',
#  'elpaisuy',
#  'infobae',
#  'izquierdadiario',
#  'laderechadiario',
#  'latercera',
#  'pagina12',
#  'perfilcom']

# %%
import json
with open("../../config/query_2.0.json") as f:
    query = json.load(f) 

query
# Out:
# {'users': ['LANACION', 'clarincom', 'cronica', 'infobae', 'perfilcom'],
#  'min_date': '2020-02-10T00:00:00Z',
#  'search_terms': ['coronavirus',
#   'covid',
#   'cuarentena',
#   'normalidad',
#   'aislamiento ',
#   'padecimiento',
#   'encierro',
#   'fase',
#   'infectados',
#   'Wuhan',
#   'distanciamiento',
#   'fiebre',
#   'síntomas',
#   'dengue',
#   'aedes',
#   'mosquito',
#   'cacharro']}

# %%
import datetime

min_date = datetime.datetime.strptime(query["min_date"], "%Y-%m-%dT%H:%M:%SZ")
text_query = " ".join(query["search_terms"])

articles = Article.objects(
    user="clarincom",
    created_at__gte=min_date
).search_text(text_query)

articles.count()
# Out:
# 14974

# %%
for art in articles.order_by('-created_at').limit(10):
    print("="*80 +'\n\n')
    print(art.created_at, '\n\n')
    print(art.title, "\n\n")
    print(art.url, "\n\n")
    print(":"*30, '\n\n')
    print(art.body)
# Out:
# ...
#
#
# 2020-07-29 14:25:40
#
#
# El fantasma de la gripe española deambula por un antiguo pueblo minero de Arizona
#
#
# https://www.clarin.com/mundo/fantasma-gripe-espanola-deambula-antiguo-pueblo-minero-arizona_0_0ej3t9C9a.html?utm_term=Autofeed&utm_medium=Social&utm_source=Twitter#Echobox=1596031738
#
#
# ::::::::::::::::::::::::::::::
#
#
# "Se fue pero no será olvidado", reza la lápida de Carl Axel Carlson, fallecido de gripe española en 1918 .
#
# Su cuerpo llevó el virus a Bisbee, en aquel entonces un próspero pueblo minero de Arizona y hoy una ciudad turística que lucha por sobrevivir a la pandemia del nuevo coronavirus más de un siglo después.
#
# La gripe española "llegó en tren", explica el historiador local Mike Anderson. Carlson murió en septiembre de 1918 en una base militar en Nueva Jersey y su cuerpo fue enviado al pueblo para ser enterrado con honores militares.
#
# ...
